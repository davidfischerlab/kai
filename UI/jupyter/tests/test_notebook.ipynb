# %% [markdown]
# # Test Notebook for Kai Jupyter Interface
#
# This notebook is used to test the Jupyter interface for Kai.

# %%
# Simple test cell
import sys
print(f"Python version: {sys.version}")
